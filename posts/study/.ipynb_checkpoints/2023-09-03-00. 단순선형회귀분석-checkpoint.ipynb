# %% [raw]
# ---
# title : "00. 단순선형회귀분석"
# author : "GC"
# date : "09/03/23"
# categories : [단순선형회귀분석]
# ---

# %% [markdown]
# # 지도학습과 비지도학습
#
# * 지도학습 : 우리가 무언가 예측하고자 하는 변수가 존재 (ex : 판매율, 주가 등등)
#
#     * 회귀 : 예측하고자 하는 변수가 연속형 변수(오늘 소개하려는 단순선형회귀분석)
#     * 분류 : 예측하고자 하는 변수가 범주형 변수(채무 이행, 불이행 문제)

# %% [markdown]
# * 비지도학습 : 예측하고자 하는 타겟변수가 없고 주어진 변수들을 통해 성격이 유사한 녀석들끼리 그룹을 형성하게끔 만든다.

# %% [markdown]
# # import

# %%
# |  code-fold : true
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
import statsmodels.api as sm

from statsmodels.stats.outliers_influence \
import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP.models import (ModelSpec as MS,
summarize,poly)

# %% [markdown]
# # 상황극 : 아이스크림과 온도

# %% [markdown]
# `-`  상황극 $\to$ 날이 더울수로 아이스 아메리카노의 판매량이 증가함
#
# *  이를 바탕으로 일기예보의 온도자료를 이용하여  다음과 같은 세계의 법칙이 있다고 가정하자.

# %% [markdown]
# $$\text{아이스 아메리카노} =  2.2 \times \text{온도} + 10.2 + \varepsilon$$

# %% [markdown]
# * 우리가 해야하는 것은 최대한 저 수식에 가까운 $\beta_1 \approx 2.2, \, \beta_0 \approx 10.2$를 찾는 것이다.
#
# * 이를 수식으로 표현하면.

# %% [markdown]
# $$\text{아이스 아메리카노} \approx  2.2 \times \text{온도} + 10.2 $$

# %% [markdown]
# ## 데이터 생성

# %%
# | code-fold : true
x   = np.linspace(20,38,1000)
epsilon = np.random.normal(size=1000)
y  =  10.2 + 2.2*x + epsilon
yhat = 10.2+2.2*x
plt.plot(x,y,".",label = "실제 데이터",alpha=0.3)
plt.plot(x,yhat,".",label = "목표 모형",alpha=0.3)
plt.legend()

# %% [markdown]
# ## 최적의 $\beta$를 구하는 방법 1

# %% [markdown]
# * 구하고자 하는 법칙

# %% [markdown]
# * 베타 추정치

# %% [markdown]
# $$\hat {\beta}_1 = \frac {\sum (x-\bar x) (y -\bar y)} {\sum (x-\bar x)^2}= \frac{S_{xy}}{S_{xx}}$$

# %% [markdown]
# $$\hat {\beta}_0 = \bar {y} - \hat{\beta}_1\bar{x}$$

# %%
# code-fold : true
n = len(x)
Sxy = sum((x-np.mean(x))*(y-np.mean(y)) )
Sxx = sum((x-np.mean(x))**2)

beta1 = Sxy/Sxx

beta0 =  np.mean(y) - beta1*np.mean(x)

plt.plot(x,y,".",label = "실제 데이터",alpha=0.15)
plt.plot(x,yhat,".",label = "목표 모형",alpha=1.0)
plt.plot(x,beta1*x+beta0,".",label = "내가 만든 예측 모형",alpha=0.1)
plt.legend()

# %% [markdown]
# * 구하고자 하는 법칙

# %% [markdown]
# $$\hat{y} \approx  2.2x + 10.2 $$

# %%
beta1,beta0
# Out:
# (2.2038453815489842, 10.072026912099155)

# %% [markdown]
# ## 최적의 $\beta$를 구하는 방법 2 ($\star\star\star$)

# %% [markdown]
# `-` matrix 이용

# %% [markdown]
# $$\hat {\bf {\beta}} = \bf{(X^{\top}X)^{-1}X^{\top}Y}$$

# %% [markdown]
# $$\bf \hat Y = X \hat {\boldsymbol{\beta}} = \begin{bmatrix}
# 1  & x_{11}  & x_{12} &\dots & x_{1p} \\ 1  & x_{21}  & x_{22} &\dots & x_{2p}  \\ \dots & \dots \\  1  & x_{n1}  & x_{n2} &\dots & x_{np}\end{bmatrix}  \,\,\begin{bmatrix} \hat \beta_0  \\ \hat \beta_1  \\ \dots \\ \beta_n \end{bmatrix} $$

# %% [markdown]
# `-` X 생성

# %%
X = pd.DataFrame({"intercept" :  np.ones(len(x)),
                             "x1" : x})

Y = y.reshape(-1,1)

beta = np.linalg.inv(X.T @ X) @ X.T @Y
beta
# Out:
#            0
# 0  10.072027
# 1   2.203845

# %%
# code-fold : true
plt.plot(x,y,".",label = "실제 데이터",alpha=0.06)
plt.plot(x,yhat,".",label = "목표 모형",alpha=0.8)
plt.plot(x,np.array(X) @ beta,".",label = "내가 만든 예측 모형",alpha=0.05)
plt.legend()

# %% [markdown]
# ## 예측 성능 평가

# %%
np.mean((y-yhat)**2)
# Out:
# 0.8927051412987645

# %% [markdown]
# ***

# %% [markdown]
# # 교재 구현 1

# %%
import statsmodels.api as sm

# %% [markdown]
# `-` OLS : Ordinary Least Squares의 약자로, 주어진 데이터에서 오차의 제곱을 최소화하는
# 를  $\beta_i$추정한다.

# %%
X = pd.DataFrame({"intercept" :  np.ones(len(x)),
                             "x1" : x})

model = sm.OLS(y,X)
results = model.fit()

# %% [markdown]
# $$\hat{y} \approx  2.2x + 10.2 $$

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.316e+05
# Date:                Mon, 04 Sep 2023   Prob (F-statistic):               0.00
# Time:                        11:20:02   Log-Likelihood:                -1417.0
# No. Observations:                1000   AIC:                             2838.
# Df Residuals:                     998   BIC:                             2848.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     10.0720      0.179     56.280      0.000       9.721      10.423
# x1             2.2038      0.006    362.820      0.000       2.192       2.216
# ==============================================================================
# Omnibus:                        2.560   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                2.695
# Skew:                           0.025   Prob(JB):                        0.260
# Kurtosis:                       3.249   Cond. No.                         167.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 결과 시각화

# %%
yhat = results.predict()

plt.plot(x,y,"o",label = r"$(x,y)$",alpha=0.1)
plt.plot(x,yhat,"--",label = r"$(x,\hat {y})$")
plt.legend()

# %% [markdown]
# # 교재 구현2 (MS)

# %%
from ISLP.models import (ModelSpec as MS,
summarize,poly)

# %%
X = pd.DataFrame({"intercept" :  np.ones(len(x)),
                             "x1" : x,
                              "x2" : 2*x})

# %%
X.head()
# Out:
#    intercept         x1         x2
# 0        1.0  20.000000  40.000000
# 1        1.0  20.018018  40.036036
# 2        1.0  20.036036  40.072072
# 3        1.0  20.054054  40.108108
# 4        1.0  20.072072  40.144144

# %% [markdown]
# ## step 1. 전달할 `x`를 다음과 같이 전달

# %%
design = MS(["x1"])

# %% [markdown]
# ## step 2. 컴퓨터가 이해할 수 있는 형태에 맞게 $\bf{X}$를 생성

# %%
_X = design.fit_transform(X)

# %%
_X
# Out:
#      intercept         x1
# 0          1.0  20.000000
# 1          1.0  20.018018
# 2          1.0  20.036036
# 3          1.0  20.054054
# 4          1.0  20.072072
# ..         ...        ...
# 995        1.0  37.927928
# 996        1.0  37.945946
# 997        1.0  37.963964
# 998        1.0  37.981982
# 999        1.0  38.000000
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## step3. 모델 적합

# %%
model = sm.OLS(y, _X)
results = model.fit()

# %% [markdown]
# ## step4. 결과 확인

# %%
summarize(results)
# Out:
#               coef  std err       t  P>|t|
# intercept  10.0720    0.179   56.28    0.0
# x1          2.2038    0.006  362.82    0.0

# %%
report = results.summary()
report
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.316e+05
# Date:                Mon, 04 Sep 2023   Prob (F-statistic):               0.00
# Time:                        10:37:22   Log-Likelihood:                -1417.0
# No. Observations:                1000   AIC:                             2838.
# Df Residuals:                     998   BIC:                             2848.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     10.0720      0.179     56.280      0.000       9.721      10.423
# x1             2.2038      0.006    362.820      0.000       2.192       2.216
# ==============================================================================
# Omnibus:                        2.560   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                2.695
# Skew:                           0.025   Prob(JB):                        0.260
# Kurtosis:                       3.249   Cond. No.                         167.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## step5. 결과 시각화

# %%
x = _X["x1"]
yhat = results.predict()

# %%
plt.plot(x,y,"o",label = r"$(x,y)$",alpha=0.3)
plt.plot(x,yhat,"--",label = r"$(x,\hat {y})$")
plt.legend()
